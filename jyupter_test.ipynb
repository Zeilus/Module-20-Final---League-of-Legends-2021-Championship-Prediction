# %%
# Dependencies
import pandas as pd

# %%
# Read data set
pd.read_csv(".//Resources//lol_dataset.csv")
# Out:
#     Team    Player Opponent Position Champion  Kills  Deaths  Assists  \
# 0    UOL      Boss       GS      Top  Camille      4       5        3
# 1     GS     Crazy      UOL      Top     Gwen      3       1        9
# 2    UOL  Ahahacik       GS   Jungle  Trundle      2       4        5
# 3     GS    Mojito      UOL   Jungle    Talon      5       4       10
# 4    UOL    Nomanz       GS      Mid  Leblanc      1       3        4
# ..   ...       ...      ...      ...      ...    ...     ...      ...
# 215  BYG     Maoan      UOL      Mid     Ryze      4       4        2
# 216  UOL  Argonavt      BYG      Adc    Senna      1       3        9
# 217  BYG     Doggo      UOL      Adc   Draven     10       2        4
# 218  UOL    Santas      BYG  Support   Wukong      0       4        7
# 219  BYG      Kino      UOL  Support    Rakan      0       5        9
#
#      Creep Score  Gold Earned  Champion Damage Share  Kill Participation  \
# ...

# %%
df = pd.read_csv(".//Resources//lol_dataset.csv")

# %%
df["Player"].value_counts()
# Out:
# Blaber        5
# Yutapon       5
# Argonavt      5
# Evi           5
# Maoan         5
# Husha         5
# Fudge         5
# Steal         5
# Doggo         5
# Zven          5
# Aria          5
# Kino          5
# Perkz         5
# Ahahacik      5
# Nomanz        5
# Santas        5
# Gaeng         5
# Boss          5
# Crazy         4
# Tally         4
# Tarzan        4
# Willer        4
# Vizicsacsi    4
# Ackerman      4
# Titan         4
# Guigo         4
# Violet        4
# Ale           4
# Deft          4
# Buggax        4
# Icon          4
# Solidsnake    4
# Light         4
# Bolulu        4
# Jojo          4
# Chovy         4
# Morgan        4
# Iwandy        4
# Whitelotus    4
# Cody          4
# Aladoric      4
# Vulcan        4
# Mojito        4
# Liang         4
# Alive         4
# Grevthar      4
# Aegis         4
# Babip         3
# Vsta          3
# Zergsting     3
# Bulcan        1
# Zersting      1
# Leona         1
# Pk            1
# Bapip         1
# ...
